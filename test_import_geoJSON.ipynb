# %%
from bioio import BioImage
from matplotlib import pyplot as plt
import numpy as np
import skimage
from scipy import stats, ndimage
import os
import shapely

# %%
filepath = ('..\\data\\D1A_rep 25.nd2 - D1A_rep 25.nd2 (series 1).geojson')

with open(filepath, 'r') as f:
    shape = shapely.from_geojson(f.read())
    # shapely.from_geojson

# %%
print(shape.exterior.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for geometry in shape:
#       2     print(geometry)
#
# TypeError: 'GeometryCollection' object is not iterable
